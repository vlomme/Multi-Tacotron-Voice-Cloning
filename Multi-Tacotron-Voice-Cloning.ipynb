# %% [markdown]
# Make sure GPU is enabled
# Runtime -> Change Runtime Type -> Hardware Accelerator -> GPU

# %%
# !git clone https://github.com/vlomme/Multi-Tacotron-Voice-Cloning.git
# Out:
# Cloning into 'Multi-Tacotron-Voice-Cloning'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
cd Multi-Tacotron-Voice-Cloning/
# Out:
# /content/Real-Time-Voice-Cloning

# %%
# !pip install -r requirements.txt
# Out:
# Collecting tensorflow-gpu<=1.14.0,>=1.10.0 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 50kB/s
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.3.9)
# Collecting visdom (from -r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/97/c4/5f5356fd57ae3c269e0e31601ea6487e0622fedc6756a591e4a5fd66cc7a/visdom-0.1.8.8.tar.gz (1.4MB)
#      |████████████████████████████████| 1.4MB 46.8MB/s
# Collecting webrtcvad (from -r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/89/34/e2de2d97f3288512b9ea56f92e7452f8207eb5a0096500badf9dfd48f5e6/webrtcvad-2.0.10.tar.gz (66kB)
#      |████████████████████████████████| 71kB 32.5MB/s
# Requirement already satisfied: librosa>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: matplotlib>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (1.16.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (4.28.1)
# Collecting sounddevice (from -r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/d1/f2/7cb487ac7171dfade8af7a368bd8806ecff82016f4ac9894835cd7de9ecc/sounddevice-0.3.13-py2.py3-none-any.whl
# Collecting Unidecode (from -r requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 67.1MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 12)) (2.1.0)
# Collecting PyQt5 (from -r requirements.txt (line 13))
#   Downloading https://files.pythonhosted.org/packages/85/bd/8a0c863802449f35ad9ca21a1b73190639c206758b4b5e2425617fc99ce9/PyQt5-5.13.0-5.13.0-cp35.cp36.cp37.cp38-abi3-manylinux1_x86_64.whl (62.1MB)
#      |████████████████████████████████| 62.1MB 74.8MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 14)) (0.70.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 15)) (0.40.1)
# Collecting libportaudio2 (from -r requirements.txt (line 16))
#   ERROR: Could not find a version that satisfies the requirement libportaudio2 (from -r requirements.txt (line 16)) (from versions: none)
# ERROR: No matching distribution found for libportaudio2 (from -r requirements.txt (line 16))

# %%
# !gdown https://drive.google.com/uc?id=1aQBmpflbX_ePUdXTSNE4CfEL9hdG2-O8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aQBmpflbX_ePUdXTSNE4CfEL9hdG2-O8
# To: /content/Multi-Tacotron-Voice-Cloning/pretrained.zip
# 398MB [00:05, 79.2MB/s]

# %%
# !unzip pretrained.zip
# Out:
# Archive:  pretrained.zip
#    creating: encoder/saved_models/
#   inflating: encoder/saved_models/pretrained.pt
#    creating: synthesizer/saved_models/
#    creating: synthesizer/saved_models/logs-pretrained/
#    creating: synthesizer/saved_models/logs-pretrained/taco_pretrained/
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/checkpoint
#    creating: vocoder/saved_models/
#    creating: vocoder/saved_models/pretrained/
#   inflating: vocoder/saved_models/pretrained/pretrained.pt
#    creating: g2p/log/
#   inflating: g2p/log/checkpoint
#   inflating: g2p/log/my_model_loss_0.04_per_0.03-165024.data-00000-of-00001
#   inflating: g2p/log/my_model_loss_0.04_per_0.03-165024.index
#   inflating: g2p/log/my_model_loss_0.04_per_0.03-165024.meta
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/tacotron_model.ckpt-332000.data-00000-of-00001
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/tacotron_model.ckpt-332000.index
#   inflating: synthesizer/saved_models/logs-pretrained/taco_pretrained/tacotron_model.ckpt-332000.meta

# %%
# !apt-get install libportaudio2

# %%
# !python demo_cli.py --no_sound
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0826 11:53:24.270652 139707603752832 deprecation_wrapper.py:119] From /content/Multi-Tacotron-Voice-Cloning/synthesizer/models/modules.py:91: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# Traceback (most recent call last):
#   File "demo_cli.py", line 4, in <module>
#     from encoder import inference as encoder
#   File "/content/Multi-Tacotron-Voice-Cloning/encoder/inference.py", line 3, in <module>
#     from encoder.audio import preprocess_wav   # We want to expose this function from here
#   File "/content/Multi-Tacotron-Voice-Cloning/encoder/audio.py", line 6, in <module>
#     import webrtcvad
# ModuleNotFoundError: No module named 'webrtcvad'

# %%
import IPython.display as ipd
print("original(оригинальный)")
ipd.display(ipd.Audio('demo_output_00.wav'))#filepath to reference voice (Путь до оригинального файла)
print("cloned(клонированный)")
ipd.display(ipd.Audio('demo_output_00.wav'))#filepath to synthesized voices (Путь до синтезированного файла)
# Out:
# original(оригинальный)
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# cloned(клонированный)
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
